# %% [markdown]
# Modulo que calcula a raiz quadrada

# %%
import math
math.sqrt(16)  # Tirando a raiz
# Out:
# 4.0

# %%
import math as o  
o.sqrt(25)
# Out:
# 5.0

# %% [markdown]
# Trabalhar com tabelas de elementos
# pandas nos permite organizar os dados das tabelas
# Uma blibloteca de gráficos
# Ajuda a trabalhar com númeors aleatórios
# Análise esttística

# %%
import numpy                       # cria colunas 
import pandas
import matplotlib
import random                      # indica a probabilidade de um número acontecer de 0 a 1
import statsmodels

# %% [markdown]
# Array são estruturas de dados.Todos tem que ser números inteiros ou decimais.

# %%
import numpy as np
a = np.array ([[0,1,2,3,5], [4,5,6,7,5], [4,5,6,7,5]])
a

print(a.shape)  # Indica a quantidade de lsitas e elementos contidos na lista.

a[2,1] = 80      # A o primeiro númeor indica a lista e o segundo indica a posição dentro da lista. 
a
# Out:
# (3, 5)
# array([[ 0,  1,  2,  3,  5],
#        [ 4,  5,  6,  7,  5],
#        [ 4, 80,  6,  7,  5]])

# %%
import random
prob = random.random()
print (prob)
# Out:
# 0.8968461401039833

# %%
number = random.randint(3,10)       # Função que gera um número aleatório. Nesse caso, gera de 3 até 10.
print (number)
# Out:
# 7
