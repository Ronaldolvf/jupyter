# %%
import numpy as np
import pandas as pd
from pandas_datareader import data as wb
import matplotlib.pyplot as plt
import matplotlib as mpl
import datetime as dt
import matplotlib.pyplot as fig
import seaborn as sns

# %%
tickers = [ "BBDC4.SA","BBAS3.SA", "ITUB4.SA", "SANB4.SA", "BIDI11.SA"] #"^BVSP"
mydata = pd.DataFrame()
for t in tickers:
    mydata[t] = wb.DataReader(t, data_source = 'yahoo', start = "2021") ['Adj Close']  #Adj Close é a coluna
print (mydata.head().round(2))
print (mydata.tail().round(2))
# Out:
#             BBDC4.SA  BBAS3.SA  ITUB4.SA  SANB4.SA  BIDI11.SA
# Date
# 2021-01-04     20.77     33.86     29.71     20.88      32.41
# 2021-01-05     20.65     33.51     29.51     20.36      31.52
# 2021-01-06     21.33     34.27     30.38     21.09      31.40
# 2021-01-07     21.90     35.64     31.56     21.73      32.79
# 2021-01-08     21.71     35.84     31.55     21.60      39.14
#             BBDC4.SA  BBAS3.SA  ITUB4.SA  SANB4.SA  BIDI11.SA
# Date
# 2022-05-02     17.95     32.98     23.75     16.55      14.78
# 2022-05-03     18.07     33.66     23.87     16.71      14.75
# 2022-05-04     18.33     34.64     23.84     17.12      15.60
# 2022-05-05     17.73     33.74     23.29     16.84      14.14
# 2022-05-06     18.12     34.01     23.77     17.32      13.43

# %%
colocando_em_ordem = sorted(mydata["BBDC4.SA"].head(5))
colocando_em_ordem
# Out:
# [20.64503288269043,
#  20.771682739257812,
#  21.329275131225586,
#  21.706783294677734,
#  21.895540237426758]

# %%
correlacao = mydata.corr()
correlacao

# 0.215357 BBDC4 BBAS3
# 0.196390 BBAS3 ITUB4
# 0.817275 BBDC4 ITUB4
# Out:
#            BBDC4.SA  BBAS3.SA  ITUB4.SA  SANB4.SA  BIDI11.SA
# BBDC4.SA   1.000000  0.191098  0.819766  0.797636   0.599404
# BBAS3.SA   0.191098  1.000000  0.174093  0.135756  -0.460375
# ITUB4.SA   0.819766  0.174093  1.000000  0.879202   0.579745
# SANB4.SA   0.797636  0.135756  0.879202  1.000000   0.461829
# BIDI11.SA  0.599404 -0.460375  0.579745  0.461829   1.000000

# %%
mydata = mydata["SANB4.SA"].rolling(252).corr(mydata["ITUB4.SA"])
mydata
# Out:
# Date
# 2021-01-04         NaN
# 2021-01-05         NaN
# 2021-01-06         NaN
# 2021-01-07         NaN
# 2021-01-08         NaN
#                 ...
# 2022-05-02    0.879037
# 2022-05-03    0.879371
# 2022-05-04    0.879550
# 2022-05-05    0.879930
# 2022-05-06    0.879996
# Length: 333, dtype: float64

# %%
mydata = mydata.dropna()
mydata.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
mydata.iloc[1].round(2)
# Out:
# nan

# %%
(mydata / mydata.iloc[0]).plot( figsize = (25,13),
                                     ls = "--",          # Formarto da linha. 
                                     lw = "2")           # Tamanho da linha. 
                                                           
plt.legend(loc = "lower left", fontsize = "12" )                          # Para desloca para a esquerda. 
plt.title ("Cotação bancos 2022", color = "black", fontsize = "30")        # Titulo da planilha.
plt.ylabel ("Cotação", fontsize = "22")                                    # Nome lateral.                         
plt.xlabel("Data", fontsize = "22" )                                       # Nome inferior. 
plt.yticks (fontsize = "12")
plt.xticks ([])

plt.show()

# %% [raw]
# ##############################################################################################################################

# %%
tickers = [ "BRL=X", "TRY=X", "ZAR=X", "MXN=X", "RUB=x"]
mydata = pd.DataFrame()
for t in tickers:
    mydata[t] = wb.DataReader(t, data_source = 'yahoo', start = '2022') ['Adj Close']  #Adj Close é a coluna
print (mydata.head())
print (mydata.tail())
# Out:
#                BRL=X    TRY=X     ZAR=X      MXN=X      RUB=x
# Date
# 2022-01-03  5.569300  13.3566  15.92990  20.481600  74.986000
# 2022-01-04  5.681200  13.0617  15.86150  20.486000  74.371803
# 2022-01-05  5.676200  13.4115  15.99912  20.521999  75.263000
# 2022-01-06  5.705635  13.6880  15.85063  20.563700  76.661598
# 2022-01-07  5.682400  13.7821  15.69730  20.493099  76.353699
#              BRL=X     TRY=X     ZAR=X      MXN=X      RUB=x
# Date
# 2022-04-25  4.8762  14.77190  15.67310  20.214600  75.739998
# 2022-04-26  4.9978  14.79970  15.82465  20.380320  74.214996
# 2022-04-27  4.9636  14.80980  15.86366  20.372299  73.839996
# 2022-04-28  4.9378  14.78889  15.98250  20.441299  72.714996
# 2022-05-02  5.0491  14.88790  16.17518  20.450001  70.175003

# %%
mydata.iloc[0]
# Out:
# BRL=X     5.5693
# TRY=X    13.3566
# ZAR=X    15.9299
# MXN=X    20.4816
# RUB=x    74.9860
# Name: 2022-01-03 00:00:00, dtype: float64

# %%
(mydata / mydata.iloc[0] * 100).plot(figsize = (30, 15),
                                                lw = "2");
plt.ylabel ("Cotação", fontsize = "22");
plt.legend(loc = "lower left", fontsize = "15" ) 

plt.show()

# %% [raw]
# ##############################################################################################################################

# %%
dados = pd.read_csv('IBOVDiA3.csv')    # Importando os dados dp aquivo csv.
display(dados)
# Out:
#    Unnamed: 0 Unnamed: 1        CD
# 0       RRRP3        .SA  RRRP3.SA
# 1       ALPA4        .SA  ALPA4.SA
# 2       ABEV3        .SA  ABEV3.SA
# 3       AMER3        .SA  AMER3.SA
# 4       ASAI3        .SA  ASAI3.SA
# ..        ...        ...       ...
# 86      VALE3        .SA  VALE3.SA
# 87      VIIA3        .SA  VIIA3.SA
# 88      VBBR3        .SA  VBBR3.SA
# 89      WEGE3        .SA  WEGE3.SA
# 90      YDUQ3        .SA  YDUQ3.SA
#
# [91 rows x 3 columns]

# %%
tickers = dados["CD"]
inicio = dt.datetime(2022,4,11)
fim    = dt.datetime(2022,4,12)
lista = tickers
df = wb.DataReader (lista, "yahoo", inicio, fim) 
df
# Out:
# Attributes  Adj Close                                                     \
# Symbols      RRRP3.SA ALPA4.SA ABEV3.SA   AMER3.SA   ASAI3.SA   AZUL4.SA
# Date
# 2022-04-11  44.139999    23.58    15.20  28.100000  15.871178  23.879999
# 2022-04-12  44.230000    22.75    15.05  28.700001  16.317554  23.660000
#
# Attributes                                          ...   Volume           \
# Symbols    B3SA3.SA  BIDI11.SA BPAN4.SA   BBSE3.SA  ... VIVT3.SA TIMS3.SA
# Date                                                ...
# 2022-04-11    14.88  18.260000     9.85  25.930000  ...   975900  4953300
# 2022-04-12    14.35  16.700001     9.60  25.709999  ...  1742100  4859300
#
# Attributes                                                                    \
# Symbols    TOTS3.SA UGPA3.SA  USIM5.SA  VALE3.SA  VIIA3.SA VBBR3.SA WEGE3.SA
# Date
# 2022-04-11  3625800  2516300  24495800  16515800  61188600  5481500  8741200
# 2022-04-12  3409500  6932700  13994700  16822600  64557000  5305200  7807000
#
# Attributes
# Symbols    YDUQ3.SA
# Date
# 2022-04-11  2624000
# 2022-04-12  4424800
#
# [2 rows x 546 columns]

# %%
df['Close'] = df['Close'].pct_change()       # Calculando a variação diária da ação.
df.head()
# Out:
# Attributes  Adj Close                                                     \
# Symbols      RRRP3.SA ALPA4.SA ABEV3.SA   AMER3.SA   ASAI3.SA   AZUL4.SA
# Date
# 2022-04-11  44.139999    23.58    15.20  28.100000  15.871178  23.879999
# 2022-04-12  44.230000    22.75    15.05  28.700001  16.317554  23.660000
#
# Attributes                                          ...   Volume           \
# Symbols    B3SA3.SA  BIDI11.SA BPAN4.SA   BBSE3.SA  ... VIVT3.SA TIMS3.SA
# Date                                                ...
# 2022-04-11    14.88  18.260000     9.85  25.930000  ...   975900  4953300
# 2022-04-12    14.35  16.700001     9.60  25.709999  ...  1742100  4859300
#
# Attributes                                                                    \
# Symbols    TOTS3.SA UGPA3.SA  USIM5.SA  VALE3.SA  VIIA3.SA VBBR3.SA WEGE3.SA
# Date
# 2022-04-11  3625800  2516300  24495800  16515800  61188600  5481500  8741200
# 2022-04-12  3409500  6932700  13994700  16822600  64557000  5305200  7807000
#
# Attributes
# Symbols    YDUQ3.SA
# Date
# 2022-04-11  2624000
# 2022-04-12  4424800
#
# [2 rows x 546 columns]

# %%
test = pd.DataFrame(df['Close'].round(4)*100)
test
# Out:
# Symbols     RRRP3.SA  ALPA4.SA  ABEV3.SA  AMER3.SA  ASAI3.SA  AZUL4.SA  \
# Date
# 2022-04-11       NaN       NaN       NaN       NaN       NaN       NaN
# 2022-04-12       0.2     -3.52     -0.99      2.14      2.81     -0.92
#
# Symbols     B3SA3.SA  BIDI11.SA  BPAN4.SA  BBSE3.SA  ...  VIVT3.SA  TIMS3.SA  \
# Date                                                 ...
# 2022-04-11       NaN        NaN       NaN       NaN  ...       NaN       NaN
# 2022-04-12     -3.56      -8.54     -2.54     -0.85  ...     -1.01      -1.6
#
# Symbols     TOTS3.SA  UGPA3.SA  USIM5.SA  VALE3.SA  VIIA3.SA  VBBR3.SA  \
# Date
# 2022-04-11       NaN       NaN       NaN       NaN       NaN       NaN
# 2022-04-12      0.99      3.21      0.62     -0.67       0.0     -0.41
#
# Symbols     WEGE3.SA  YDUQ3.SA
# Date
# 2022-04-11       NaN       NaN
# 2022-04-12     -0.55     -3.63
#
# [2 rows x 91 columns]

# %%
variacao_ibov = test.iloc[1].round(2)       # Com o iloc, está buscando os dados que se encontram na segunda linha.
variacao_ibov
# Out:
# Symbols
# RRRP3.SA    0.20
# ALPA4.SA   -3.52
# ABEV3.SA   -0.99
# AMER3.SA    2.14
# ASAI3.SA    2.81
#             ...
# VALE3.SA   -0.67
# VIIA3.SA    0.00
# VBBR3.SA   -0.41
# WEGE3.SA   -0.55
# YDUQ3.SA   -3.63
# Name: 2022-04-12 00:00:00, Length: 91, dtype: float64

# %%
variacao_ibov.to_excel('variacao_ibov.xlsx')

# %% [raw]
# ###############################################################################################################################

# %%
dados = pd.read_csv('IMATDia_05-04-22.csv')    
dados.head(2)
# Out:
#      Código       Ação
# 0  BRAP4.SA  BRADESPAR
# 1  BRKM5.SA    BRASKEM

# %%
tickers = dados["Código"]
tickers.head(2)
# Out:
# 0    BRAP4.SA
# 1    BRKM5.SA
# Name: Código, dtype: object

# %%
tickers = dados["Código"]
inicio = dt.datetime(2022,3,31)
fim    = dt.datetime(2022,4,8)
lista = tickers
df = wb.DataReader (lista, "yahoo", inicio, fim) 
df
# Out:
# Attributes  Adj Close                                                   \
# Symbols      BRAP4.SA   BRKM5.SA   CBAV3.SA CMIN3.SA DXCO3.SA DEXP3.SA
# Date
# 2022-03-31  33.080002  44.299999  20.049999     6.03    14.68     8.64
# 2022-04-01  34.029999  44.400002  19.930000     6.12    14.53     8.64
# 2022-04-04  34.080002  44.540001  19.969999     6.20    14.72     8.60
# 2022-04-05  33.549999  43.070000  19.540001     5.96    14.20     8.12
# 2022-04-06  33.730000  42.529999  19.280001     5.91    13.60     7.66
# 2022-04-07  33.500000  45.490002  18.350000     5.88    13.84     7.87
# 2022-04-08  32.849998  44.139999  17.889999     5.83    13.60     7.80
#
# Attributes                                          ...    Volume           \
# Symbols      FESA4.SA   GGBR4.SA GOAU4.SA RANI3.SA  ...  GGBR4.SA GOAU4.SA
# Date                                                ...
# 2022-03-31  47.619999  30.809999    12.26     6.80  ...   9639000  6121000
# 2022-04-01  46.810001  30.639999    12.24     6.67  ...  12929400  7322300
# 2022-04-04  47.000000  30.160000    12.14     6.86  ...   7467400  6526700
# 2022-04-05  46.020000  30.139999    12.04     6.70  ...  11749400  8295000
# 2022-04-06  47.139999  30.020000    11.98     6.68  ...   9235000  8149000
# 2022-04-07  45.360001  29.290001    11.66     6.61  ...  16609800  7285900
# 2022-04-08  44.400002  29.389999    11.74     6.52  ...  14261800  8631900
#
# Attributes                                                                     \
# Symbols    RANI3.SA KLBN11.SA  CSNA3.SA  SUZB3.SA UNIP6.SA USIM3.SA  USIM5.SA
# Date
# 2022-03-31   953400   5761200  10192900   7851400   391490   294700  17809500
# 2022-04-01  1376000   5742500   7572900  10746000   351780   777300  20373600
# 2022-04-04  1216900   5049400   7040900   5450100   389290   494300  19272700
# 2022-04-05  1016800   5874100   6181100   6634800   450340   606300  16313900
# 2022-04-06  1005700   8702200   8216100   7346500   388080   372400  15776100
# 2022-04-07  1645000   4690300   6629000   5138700   308880   301200  12720400
# 2022-04-08   656800   4742300   8577600   4374700   330660   499300  24661600
#
# Attributes
# Symbols     VALE3.SA
# Date
# 2022-03-31  17981400
# 2022-04-01  22457700
# 2022-04-04  16914000
# 2022-04-05  25764400
# 2022-04-06  22615800
# 2022-04-07  19946600
# 2022-04-08  26887400
#
# [7 rows x 102 columns]

# %%
df['Close'] = df['Close'].pct_change()       # Calculando a variação diária da ação.
test = pd.DataFrame(df['Close'].round(4)*100)
test
# Out:
# Symbols     BRAP4.SA  BRKM5.SA  CBAV3.SA  CMIN3.SA  DXCO3.SA  DEXP3.SA  \
# Date
# 2022-03-31       NaN       NaN       NaN       NaN       NaN       NaN
# 2022-04-01      2.87      0.23     -0.60      1.49     -1.02      0.00
# 2022-04-04      0.15      0.32      0.20      1.31      1.31     -0.46
# 2022-04-05     -1.56     -3.30     -2.15     -3.87     -3.53     -5.58
# 2022-04-06      0.54     -1.25     -1.33     -0.84     -4.23     -5.67
# 2022-04-07     -0.68      6.96     -4.82     -0.51      1.76      2.74
# 2022-04-08     -1.94     -2.97     -2.51     -0.85     -1.73     -0.89
#
# Symbols     FESA4.SA  GGBR4.SA  GOAU4.SA  RANI3.SA  KLBN11.SA  CSNA3.SA  \
# Date
# 2022-03-31       NaN       NaN       NaN       NaN        NaN       NaN
# 2022-04-01     -1.70     -0.55     -0.16     -1.91      -1.62      0.46
# 2022-04-04      0.41     -1.57     -0.82      2.85      -0.76      1.07
# 2022-04-05     -2.09     -0.07     -0.82     -2.33      -1.27     -2.57
# 2022-04-06      2.43     -0.40     -0.50     -0.30       1.38     -2.80
# 2022-04-07     -3.78     -2.43     -2.67     -1.05      -1.65      0.56
# 2022-04-08     -2.12      0.34      0.69     -1.36       0.39      2.22
#
# Symbols     SUZB3.SA  UNIP6.SA  USIM3.SA  USIM5.SA  VALE3.SA
# Date
# 2022-03-31       NaN       NaN       NaN       NaN       NaN
# 2022-04-01     -1.70     -1.73     -1.38     -1.43      1.42
# 2022-04-04     -0.17     -1.71      2.26      1.96      1.01
# 2022-04-05      0.09      1.03     -2.89     -2.42     -2.89
# 2022-04-06      2.16      1.32     -1.88     -1.02      1.51
# 2022-04-07     -1.57     -0.32      0.64     -0.15      0.60
# 2022-04-08      0.06     -2.25     -2.38     -3.62     -2.04

# %%
test.to_excel('variacao_imob.xlsx')

# %% [raw]
# ###############################################################################################################################

# %%
inicio = dt.datetime(2022,1,1)
fim    = dt.datetime(2022,5,2)
lista  = ["BBDC4.SA", "BBAS3.SA","ITUB4.SA","SANB4.SA"]
df     = wb.DataReader (lista, "yahoo", inicio, fim)
df["Close"].plot( 
                 lw = 3, 
                 figsize = (20, 10)
                 )
                                           
fig.title("BANCOS (JAN - NOV 2019)", fontsize = 30, weight = "bold")
fig.yticks (fontsize = 15)
plt.xticks (fontsize = 15)
# Out:
# (array([18993., 19007., 19024., 19038., 19052., 19066., 19083., 19097.,
#         19113.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])
