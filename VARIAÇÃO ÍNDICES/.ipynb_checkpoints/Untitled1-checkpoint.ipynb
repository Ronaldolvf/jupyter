# %%
import numpy as np
import pandas as pd
from pandas_datareader import data as wb
import matplotlib.pyplot as plt
import matplotlib as mpl
import datetime as dt
import matplotlib.pyplot as fig
import seaborn as sns
import bar_chart_race as bcr
import time

# %%
dados = pd.read_csv('infla.csv')   
dados
# Out:
#     ano  1981  1982   1983   1984   1985   1986   1987   1988   1989  ...  \
# 0   jan  6,82  8,32  10,45  10,14  14,61  16,23  13,21  18,89  37,49  ...
# 1   fev  6,15  6,14   6,06   9,10   8,95  14,36  12,64   15,7  16,78  ...
# 2   mar   5,1  6,36   8,54   8,98  12,78  -0,11  16,37   17,6   6,82  ...
# 3   abr  5,04  5,18    7,8   9,23    8,8   0,78   19,1  19,29   8,33  ...
# 4   mai  7,39  6,46   5,57   9,88   6,76    1,4  21,45  17,42  17,92  ...
# 5   jun  3,97  7,38   7,87   8,14   7,71   1,27  19,71     22  28,65  ...
# 6   jul  6,69  6,54  12,06  12,62   9,27   1,71   9,21  21,91  27,74  ...
# 7   ago  6,28  5,94   8,32   7,32   12,1   3,55   4,87  21,59  33,71  ...
# 8   set  5,29  5,61   9,48  11,39  11,98   1,72   7,78  27,45  37,56  ...
# 9   out  4,57  4,59   10,9  10,87    9,6    1,9  11,22  25,62  39,77  ...
# 10  nov  5,88  4,59   6,96  10,35  11,12   5,45  15,08  27,94  47,82  ...
# 11  dez  4,37  6,04   7,44  10,35  13,36  11,65  14,15   28,7   51,5  ...
#
#     1995  1996   1997   1998  1999  2000  2001  2002   2003  2004
# 0    1,7  1,34   1,18   0,71   0,7  0,62  0,57  0,52   2,25  0,76
# 1   1,02  1,03    0,5   0,46  1,05  0,13  0,46  0,36   1,57  0,61
# 2   1,55  0,35   0,51   0,34   1,1  0,22  0,38   0,6   1,23  0,47
# 3   2,43  1,26   0,88   0,24  0,56  0,42  0,58   0,8   0,97  0,37
# 4   2,67  1,22   0,41    0,5   0,3  0,01  0,41  0,21   0,61  0,51
# 5   2,26  1,19   0,54   0,02  0,19  0,23  0,52  0,42  -0,15  0,71
# 6   2,36  1,11   0,22  -0,12  1,09  1,61  1,33  1,19    0,2  0,91
# 7   0,99  0,44  -0,02  -0,51  0,56  1,31   0,7  0,65   0,34  0,69
# 8   0,99  0,15   0,06  -0,22  0,31  0,23  0,28  0,72   0,78  0,33
# 9   1,41   0,3   0,23   0,02  1,19  0,14  0,83  1,31   0,29  0,44
# 10  1,47  0,32   0,17  -0,12  0,95  0,32  0,71  3,02   0,34  0,69
# 11  1,56  0,47   0,43   0,33   0,6  0,59  0,65   2,1   0,52  0,86
#
# [12 rows x 25 columns]

# %%
df.drop (columns= {
                    0 : "ano", 
                    1 : 80})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_29300/3897638595.py in <module>
# ----> 1 df.drop (columns= {
#       2                     0 : "ano",
#       3                     1 : 80})
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
#    4149             if labels is not None:
# -> 4150                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4151
#    4152         if inplace:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    4183                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4184             else:
# -> 4185                 new_axis = axis.drop(labels, errors=errors)
#    4186             result = self.reindex(**{axis_name: new_axis})
#    4187
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    6015         if mask.any():
#    6016             if errors != "ignore":
# -> 6017                 raise KeyError(f"{labels[mask]} not found in axis")
#    6018             indexer = indexer[~mask]
#    6019         return self.delete(indexer)
#
# KeyError: '[0 1] not found in axis'

# %%
bcr.bar_chart_race(dados, fixed_max=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_29300/1827075971.py in <module>
# ----> 1 bcr.bar_chart_race(dados, fixed_max=True)
#
# ~\anaconda3\lib\site-packages\bar_chart_race\_make_chart.py in bar_chart_race(df, filename, orientation, sort, n_bars, fixed_order, fixed_max, steps_per_period, period_length, interpolate_period, label_bars, bar_size, period_label, period_fmt, period_summary_func, perpendicular_bar_func, figsize, cmap, title, title_size, bar_label_size, tick_label_size, shared_fontdict, scale, writer, fig, dpi, bar_kwargs, filter_column_colors)
#     776     These sizes are relative to plt.rcParams['font.size'].
#     777     '''
# --> 778     bcr = _BarChartRace(df, filename, orientation, sort, n_bars, fixed_order, fixed_max,
#     779                         steps_per_period, period_length, interpolate_period, label_bars, bar_size,
#     780                         period_label, period_fmt, period_summary_func, perpendicular_bar_func,
#
# ~\anaconda3\lib\site-packages\bar_chart_race\_make_chart.py in __init__(self, df, filename, orientation, sort, n_bars, fixed_order, fixed_max, steps_per_period, period_length, interpolate_period, label_bars, bar_size, period_label, period_fmt, period_summary_func, perpendicular_bar_func, figsize, cmap, title, title_size, bar_label_size, tick_label_size, shared_fontdict, scale, writer, fig, dpi, bar_kwargs, filter_column_colors)
#      44         self.bar_kwargs = self.get_bar_kwargs(bar_kwargs)
#      45         self.html = self.filename is None
# ---> 46         self.df_values, self.df_ranks = self.prepare_data(df)
#      47         self.fig, self.ax = self.get_fig(fig, dpi)
#      48         self.col_filt = self.get_col_filt()
#
# ~\anaconda3\lib\site-packages\bar_chart_race\_make_chart.py in prepare_data(self, df)
#     148
#     149         compute_ranks = self.fixed_order is False
# --> 150         dfs = prepare_wide_data(df, self.orientation, self.sort, self.n_bars,
#     151                                 self.interpolate_period, self.steps_per_period,
#     152                                 compute_ranks)
#
# ~\anaconda3\lib\site-packages\bar_chart_race\_make_chart.py in prepare_wide_data(df, orientation, sort, n_bars, interpolate_period, steps_per_period, compute_ranks)
#     896         df_ranks = df_ranks.interpolate()
#     897
# --> 898     df_values = df_values.interpolate()
#     899     if compute_ranks:
#     900         return df_values, df_ranks
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in interpolate(self, method, axis, limit, inplace, limit_direction, limit_area, downcast, **kwargs)
#   10710         **kwargs,
#   10711     ) -> DataFrame | None:
# > 10712         return super().interpolate(
#   10713             method,
#   10714             axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in interpolate(self, method, axis, limit, inplace, limit_direction, limit_area, downcast, **kwargs)
#    6864
#    6865         if obj.ndim == 2 and np.all(obj.dtypes == np.dtype("object")):
# -> 6866             raise TypeError(
#    6867                 "Cannot interpolate with all object-dtype columns "
#    6868                 "in the DataFrame. Try setting at least one "
#
# TypeError: Cannot interpolate with all object-dtype columns in the DataFrame. Try setting at least one column to a numeric dtype.
